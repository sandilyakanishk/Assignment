# %% [markdown]
# # Question 1
#
# ## Explain the key features of Python that make it a popular choice for programming.
#
# Python is one of the most popular programming languages because it is easy to learn and use. Its simple syntax makes programs readable and easy to maintain. Python is platform-independent, meaning code can run on different operating systems with minimal changes. It supports object-oriented, procedural, and functional programming paradigms. Python also has a large standard library and a huge community that provides frameworks and tools for web development, data science, machine learning, and automation.

# %% [markdown]
# # Question 2
#
# ## Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
# Predefined keywords are reserved words in Python that have special meanings and cannot be used as variable names. They define the structure and flow of a program.
#
# Example:
# ```python
# if 10 > 5:
#     print('True')
# else:
#     print('False')
# ```
# Here, 'if' and 'else' are Python keywords used for decision making.

# %% [markdown]
# # Question 3
#
# ## Compare and contrast mutable and immutable objects in Python with examples.
#
# Mutable objects can be changed after creation, while immutable objects cannot.
#
# Mutable Example:
# ```python
# my_list = [1, 2, 3]
# my_list.append(4)
# print(my_list)
# ```
#
# Immutable Example:
# ```python
# my_tuple = (1, 2, 3)
# # my_tuple[0] = 10  # Error
# ```
# Lists are mutable, whereas tuples and strings are immutable.

# %% [markdown]
# # Question 4
#
# ## Discuss the different types of operators in Python and provide examples of how they are used.
#
# Python operators include:
#
# 1. Arithmetic Operators (+, -, *, /)
# 2. Comparison Operators (==, !=, >, <)
# 3. Logical Operators (and, or, not)
# 4. Assignment Operators (=, +=, -=)
# 5. Membership Operators (in, not in)
#
# Example:
# ```python
# a = 10
# b = 5
# print(a + b)
# print(a > b)
# print(a and b)
# ```

# %% [markdown]
# # Question 5
#
# ## Explain the concept of type casting in Python with examples.
#
# Type casting is the process of converting one data type into another.
#
# Example:
# ```python
# num = '100'
# converted_num = int(num)
# print(converted_num + 50)
# ```
#
# Other functions include float(), str(), and bool().

# %% [markdown]
# # Question 6
#
# ## How do conditional statements work in Python? Illustrate with examples.
#
# Conditional statements execute different blocks of code based on conditions.
#
# Example:
# ```python
# age = 18
#
# if age >= 18:
#     print('Eligible to vote')
# else:
#     print('Not eligible')
# ```
#
# Python also supports elif for multiple conditions.

# %% [markdown]
# # Question 7
#
# ## Describe the different types of loops in Python and their use cases with examples.
#
# Python mainly provides two types of loops:
#
# 1. for loop – used when the number of iterations is known.
# 2. while loop – used when iterations depend on a condition.
#
# For Loop Example:
# ```python
# for i in range(5):
#     print(i)
# ```
#
# While Loop Example:
# ```python
# count = 1
# while count <= 5:
#     print(count)
#     count += 1
# ```
# Loops help automate repetitive tasks.
